# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def createFolder(directory):
    #저장 폴더 생성
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print('Error: Creating directory' + directory)

# %%
def changePath(directory):
    #데이터 폴더 선택
    currentPath = os.getcwd()
    change_path = currentPath+directory
    try:
        if os.path.exists(directory[1:]):
            os.chdir(change_path)
    except OSError:
        print('Error: Changing Path ' + directory)

# %%
def SavePlotPNG(current_path, file_list, save_path):
    #file_list.remove('cell')
    file_count = len(file_list)
    
    for i in range(file_count):
        
        file_path = file_list[i]
        delete_csv_path = file_path[:-4]
        df = pd.read_csv(file_path, encoding = 'utf8')
        
        os.chdir(save_path)
        plt.figure(figsize=(12,6))
        plt.plot(df.loc[:,'ResistValue'], label="ResistValue")
        plt.legend()
        plt.savefig(delete_csv_path + '.png')
        plt.show()
        os.chdir(current_path)

# %%
if __name__ =='__main__':
    createFolder('plotpng')
    currentPath = os.getcwd()
    print('현재위치', currentPath)
    print('데이터 폴더 입력(\ 포함)')
    data_folder_path = input()
# Out:
# 현재위치 F:\Personal\BatteryDatasetImplementation-master\omona\work010
# 데이터 폴더 입력(\ 포함)
# \test2

# %%
    #데이터 폴더 입력
    changePath(data_folder_path)

# %%
    os.getcwd()
    save_path = currentPath + '\plotpng'
    print(save_path)
    currentPath = os.getcwd()
    print(currentPath)
# Out:
# F:\Personal\BatteryDatasetImplementation-master\omona\work010\plotpng
# F:\Personal\BatteryDatasetImplementation-master\omona\work010\test2

# %%
    file_list = os.listdir(os.getcwd())

# %%
    column_list = ['MeasuredDate', 'ResistValue', 'Volt', 'Temp']

# %%
    SavePlotPNG(currentPath, file_list, save_path)

# %%
import pandas as pd

# %% [markdown]
# ## 노이즈도 cell 분리 시키는지 확인

# %%
x='m2_s2_bank_0053979e93612348a180e1133103725e__site_0d39d11b52565146a236a646d49133f4_22.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_0053979e93612348a180e1133103725e__site_0d39d11b52565146a236a646d49133f4_55.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Cell 분리 확인

# %%
x='m2_s2_bank_01c70366fc4e1a439e0b4516698baadf__site_40ab7c891c559b478e96f8bb5c682ca0_73.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_0765f177a52e5543a9e0a8bfc045cf6a__site_40ab7c891c559b478e96f8bb5c682ca0_34.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_ad0a39c8badd884aa05857f31cf4c009__site_896b9cbccb72864dae1704b46ccc3401_70.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_ad75c4cc2762664a92418e96b0df8956__site_3471ad4b4665ee47a6a824c7bbc7911b_27.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_add448e4063ae94cbec3c1f86f62fb2c__site_3471ad4b4665ee47a6a824c7bbc7911b_89.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_b52ed68c11136d45b8ce552e5f1d588a__site_40ab7c891c559b478e96f8bb5c682ca0_49.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_d47a03dc147d7b419ec4f14bf2ab6ebb__site_40ab7c891c559b478e96f8bb5c682ca0_30.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_b57ba6527158fa4095578709fab0e24b__site_3471ad4b4665ee47a6a824c7bbc7911b_33.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_d47a03dc147d7b419ec4f14bf2ab6ebb__site_40ab7c891c559b478e96f8bb5c682ca0_75.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_da82bfcd77777c49be518f8d198ad1b4__site_2b516e6b0157484ea5a5107444687c60_22.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_741ce5ff0b2c6742a800603091dd6fe5__site_3471ad4b4665ee47a6a824c7bbc7911b_22.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>

# %%
x='m2_s2_bank_a3615938c72db045a493474dd913bb87__site_896b9cbccb72864dae1704b46ccc3401_48.csv'
df = pd.read_csv('BANKS/cell/'+x)
df['ResistValue'].plot()
# Out:
# <AxesSubplot:>
